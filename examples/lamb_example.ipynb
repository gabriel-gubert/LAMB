# %% [markdown]
# ## Using the LAMB Provider
#
# The command structure is `%%ai [provider_id]:[model_id]`. We will use **`%%ai lamb:openai`**.
#
# You simply place this command at the top of a cell containing the legacy code you want to translate.

# %% [markdown]
# ---

# %%
# %load_ext jupyter_ai

# %%
# %ai list

# %%
# %%ai lamb:openai
